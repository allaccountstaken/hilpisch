# %%
import pandas as pd
import numpy as np
from pylab import mpl, plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
#df = pd.read_csv('http://hilpisch.com/tr_eikon_eod_data.csv')
#df.to_csv('data/tr_eikon_eod_data.csv')

# %%
filename = 'data/tr_eikon_eod_data.csv'

# %%
f = open(filename, 'r')

# %%
f.readlines()[:5]
# Out:
# [',Date,AAPL.O,MSFT.O,INTC.O,AMZN.O,GS.N,SPY,.SPX,.VIX,EUR=,XAU=,GDX,GLD\n',
#  '0,2010-01-01,,,,,,,,,1.4323,1096.35,,\n',
#  '1,2010-01-04,30.57282657,30.95,20.88,133.9,173.08,113.33,1132.99,20.04,1.4411,1120.0,47.71,109.8\n',
#  '2,2010-01-05,30.625683660000004,30.96,20.87,134.69,176.14,113.63,1136.52,19.35,1.4368,1118.65,48.17,109.7\n',
#  '3,2010-01-06,30.138541290000006,30.77,20.8,132.25,174.26,113.71,1137.14,19.16,1.4412,1138.5,49.34,111.51\n']

# %%
data = pd.read_csv(filename, index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#          Date     AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX  \
# 0  2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 1  2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99
# 2  2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52
# 3  2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14
# 4  2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69
#
#     .VIX    EUR=     XAU=    GDX     GLD
# 0    NaN  1.4323  1096.35    NaN     NaN
# 1  20.04  1.4411  1120.00  47.71  109.80
# 2  19.35  1.4368  1118.65  48.17  109.70
# 3  19.16  1.4412  1138.50  49.34  111.51
# 4  19.06  1.4318  1131.90  49.10  110.82

# %%
data.plot(figsize=(10,12), subplots=True)
plt.show()
